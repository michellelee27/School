# %% [markdown]
# Michelle Lee
# <br>
# Date: Jan. 10, 2024
# <br>
# PHYS 2030 W24

# %% [markdown]
# # <center><font color=#46769B>Exercise 0: Hello world!</font></center>
#
# This is a test exercise.
# - Please change the constants $a$ and $b$ to be different values of your choice, and run the code below.
# - Save your code to your GitHub repository for this exercise.
#
# __Rubric__ (100 points total):
#
# - Did you write your name at the top?            __50 points__
# - Did you change $a,b$ and run the code?         __50 points__

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 5
b = -10

x = np.linspace(0,10)
y = a*x + b

plt.plot(x,y)
